# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
### Cargar y visualizar datos

data = np.loadtxt("dos_picos_1.dat")
x = data[:,0]
y = data[:,1]
plt.scatter(x,y)

# %%
### Ajuste de curvas

def f(x, a, b):
    y = a + b * x
    return y

popt, pcov = curve_fit(f,x,y)

# %%
y_opt = f(x,popt[0], popt[1])
plt.scatter(x,y_opt)

# %%
def fgauss(x, ampl, x0, sigma):
    y =  ampl*np.exp(-((x-x0)**2)/sigma)
    return y

popt, pcov = curve_fit(fgauss,x,y)
print(popt)
# Out:
# [  5.03819439  12.56705022 278.3993651 ]

# %%
y_opt_gauss = fgauss(x, popt[0],popt[1],popt[2])
plt.scatter(x, y_opt_gauss)
